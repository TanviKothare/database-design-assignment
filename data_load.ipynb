# %%
# !pip install pandas sqlalchemy psycopg2
# Out:
# Requirement already satisfied: pandas in c:\tanvii\lib\site-packages (2.1.4)
# Requirement already satisfied: sqlalchemy in c:\tanvii\lib\site-packages (2.0.25)
# Requirement already satisfied: psycopg2 in c:\tanvii\lib\site-packages (2.9.11)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\tanvii\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\tanvii\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\tanvii\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\tanvii\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\tanvii\lib\site-packages (from sqlalchemy) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\tanvii\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: six>=1.5 in c:\tanvii\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("C:/Users/ayush/Desktop/Qode/3mfanddo.csv")

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:root@localhost:5432/trading_db")

# %%
df.to_sql("trade", engine, if_exists="append", index=False)
# Out:
# 575

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="trading_db",
    user="postgres",
    password="root"
)

print("Connected Successfully")
# Out:
# Connected Successfully

# %%
print("Data loaded successfully")
# Out:
# Data loaded successfully
